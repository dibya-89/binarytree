# %%
import random
choiceOwnlist=input("Do you want to insert or delete? o - own or d- default")
if choiceOwnlist=='o':
    #input_string = input('Enter elements of a list separated by space ')
    #print("\n")
    #user_list = input_string.split()
    # creating an empty list
    user_list = []
  
    # number of elements as input
    n = int(input("Enter number of elements : "))
  
    # iterating till the range
    for i in range(0, n):
        ele = int(input("Enter the element"))
  
        user_list.append(ele) # adding the element
      
    print(user_list)
else:
    list_length = int(input('Enter the length of the list: '))
    final_list = []

    for i in range(0,list_length):
        final_list.append(random.randint(1,100))
        user_list=final_list
        print(user_list)

# print list
print('Your current list: ', user_list)
# Incase not integer list is there,
# convert each item to int type
#if (all([isinstance(item, int) for item in user_list]))
 #   for i in range(len(user_list)):
    # convert each item to int type
  #      user_list[i] = int(user_list[i])
#else

#Createe a new list
#user_list = list()
#Print list
print('Current List:')
print(user_list)

print('Indices start from 0')
while True:
    choice = input("Do you want to insert or delete? i - insert, d - delete : ")
    if choice=='i':
        #For insert choice
        inputChoice= input("Where do you want to insert? ind - index, fpos - First postion, epos- End Postion ")
        if inputChoice=='ind':
            #If list is not empty
            if len(user_list) != 0:
                #Take index input from user
                idx = int(input("Enter index where you want to insert: ")) 
            else:
                idx = 0
            #Assume negative index is not suported
            if idx < 0:
                raise ValueError('Error! Negative index not supported')
            elif idx > len(user_list):
                raise IndexError('Error! Index out of range')
            else:
                value = int(input("Enter what you want to insert to array: "))
                user_list.insert(idx, value)

            #Print updated list
            print('Current List')
            print(user_list)
        elif inputChoice=='fpos':
                n = int(input("Enter the element that you want to add : "))
                user_list.insert(0,n)
                #Print updated list
                print('Updated List after adding the element at first postion of the list')
                print(user_list)
        else:
            n = int(input("Enter the element that you want to add : "))
            user_list.append(n)
            #Print updated list
            print('Updated List after adding the element at end of the list')
            print(user_list)

    elif choice=='d': 
        #For deletion
        mode = input('Enter mode of deletion, i - for index, v - value, ir- index range, mv- multiple value : , dfe- Delete First Element: , dle - Delete Last element ')
        if mode == 'i':
            #Take index input from user
            idx = int(input("Enter index from where you want to delete: "))
            #Assume negative index is not supported
            if idx < 0:
                raise ValueError('Error! Negative index not suppoerted')
            elif idx >= len(user_list):
                raise IndexError('Error! Index out or range')
            else:
                user_list.pop(idx)
                print('After Delete the given index element of list', user_list)
        elif mode == 'v':
            val = int(input('Enter value to delete : '))
            count= user_list.count(val)
            if count==1:
                while val in user_list:
                    user_list.remove(val)
                    print('After Delete the element from the list', user_list)
            else:
                print("There are multiple occuernce of your given value and the total count is : ", count)
                delCont=input ("Do you want to delete all Y- Yes, N- No")
                if delCont=='Y':
                    while val in user_list:
                        user_list.remove(val)
                        print('After Delete the elements from the list', user_list)
                    
                else:
                    idx = int(input("Enter index from where you want to delete: "))
            #Assume negative index is not supported
                    if idx < 0:
                        raise ValueError('Error! Negative index not suppoerted')
                    elif idx >= len(user_list):
                        raise IndexError('Error! Index out or range')
                    else:
                        user_list.pop(idx)
                        print('After Delete the element of list', user_list)

        elif mode == 'mv':
            # number of ele
            n = int(input("Enter how many number of elements you want to delete : "))
  
            # Below line read inputs from user using map() function 
            a = list(map(int,input("\nEnter the numbers : ").strip().split()))[:n]
            print ("List to delete", a)
            for ele in a:
                user_list.remove(ele)
            print('After Delete the elements from the list', user_list)        
        elif mode=='dfe':
            user_list.pop(0)
            print('After Delete the first element of list', user_list)
        elif mode=='dle':
            user_list.pop()
            print('After Delete the Last element of list', user_list)
        print(user_list)
        #Print updated list
        print('Current List')
        print(user_list)
    else:
        break
# Out:
# Do you want to insert or delete? o - own or d- defaulto
# Enter number of elements : 5
# Enter the element25
# Enter the element25
# Enter the element74
# Enter the element86
# Enter the element58
# [25, 25, 74, 86, 58]
# Your current list:  [25, 25, 74, 86, 58]
# Current List:
# [25, 25, 74, 86, 58]
# Indices start from 0
